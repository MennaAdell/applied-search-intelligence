# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# One Row = One specific content piece / URL page (content_id) per monthly aggregation window.
#
# Time Window: Daily and monthly historical search performance data spanning across mid-panel months (e.g., 2026-03), keeping the final month (2026-06) sealed as an unseen outcome test window.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# Features: word_count, readability_score, keyword_density, content_age_days, days_since_last_update (Predictive signals known at decision moment).
#
# Label: is_declining_label / trend_direction (The target outcome we aim to predict: whether a page is losing search performance).
#
# Context: content_id, client_id, month, primary_intent (Identifiers and metadata that define the scope but shouldn't be learned as direct predictive signals).
#
# Excluded: future_traffic_next_month or post-decision outcome metrics (Why: Excluding them to prevent direct data leakage, as they represent the future outcome we are trying to predict rather than past/current inputs).

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
import os, getpass
import duckdb

# جلب الـ Hugging Face Token بأمان
HF_TOKEN = os.environ.get('HF_TOKEN')
if not HF_TOKEN:
    try:
        from google.colab import userdata
        HF_TOKEN = userdata.get('HF_TOKEN')
    except Exception:
        pass
HF_TOKEN = HF_TOKEN or getpass.getpass('Paste your Hugging Face READ token (hf_...): ')

# الاتصال بـ DuckDB وتفعيل الـ Secret
con = duckdb.connect()
con.execute(f"CREATE OR REPLACE SECRET hf (TYPE huggingface, TOKEN '{HF_TOKEN}')")
# Out:
# Paste your Hugging Face READ token (hf_...): ··········

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# Limitation: The dataset lacks offline metrics, external search volume spikes outside our tracked clients, and off-site user behavior, meaning it cannot fully account for external marketing or brand awareness campaigns influencing traffic.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
